# %%
import pandas as pd
import warnings
import re
import numpy as np
import time
import PyPDF2
from PyPDF2 import PdfReader
import tabula
import os

# %%
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # default='warn'
warnings.simplefilter(action='ignore', category=FutureWarning)
term_size = os.get_terminal_size()

# %% [markdown]
# ### Select Scouts

# %% [markdown]
# Choose scouts

# %%
def clean_scouts():
    scout_assemble = pd.read_csv("Scouts/scouted this week.csv")
    scout_assemble.drop(list(scout_assemble.filter(regex='Unnam')), axis=1, inplace=True)
    scout_assemble["Country"] = scout_assemble["TEA Random"].str.split(" - ").str[-1] # get the country and add to new col
    scout_assemble['TEA Random'] = scout_assemble['TEA Random'].str[4:] # remove "TEA"
    scout_assemble["TEA Random"] = scout_assemble["TEA Random"].str.split(" - ").str[0]
    scout_assemble = scout_assemble.rename(columns={'TEA Random': 'Team'})

    global search_MDS_4_scouts
    search_MDS_4_scouts = scout_assemble["Team"].tolist()

clean_scouts()
search_MDS_4_scouts
# Out:
# ['Ascoli',
#  'Cannes',
#  'Douane',
#  'Santos Laguna',
#  'Incheon United',
#  'Ionikos',
#  'Longford Town',
#  'Motherwell',
#  'Excelsior Mouscron',
#  'Las Palmas']

# %% [markdown]
# Import previously scouted teams and clean up

# %%
def filter_scouts(search,return_scouts): # set function to take two variables (these will be return_scouts and search) >> see search_scouted
    print('\n')
    print('=' * term_size.columns)
    return_scouts.drop(list(return_scouts.filter(regex='Unnamed: 0')), axis=1, inplace=True)
    return_scouts.rename(columns = { "Unnamed: 1" : "Nationality" },inplace=True) # rename column
    print('\033[1m' + search + '\n') # print team name in bold
    display(return_scouts) # show the scouted teams
    print('\n')
    print('=' * term_size.columns)

# %%
import matplotlib.pyplot as plt
display(search_MDS_4_scouts)
file = pd.read_csv("Turn Data/Turn Data.csv").Filepath.squeeze() # get file path 

s_PV = 32 #= int(input("What PV threshold would you like to scout for? "))
def search_scouted(result):

    pdf_file = open(file, 'rb') # Open the PDF file
    pdf_reader = PyPDF2.PdfReader(pdf_file) # Create a PDF reader object
    search = result # set the list element as the text to search by
    
    for page_number in range(len(pdf_reader.pages)): # for each page in the range
            text = pdf_reader.pages[page_number].extract_text() # extract text of PDF page
        
            if search in text: # if list element is in the page text
                page = page_number + 1 # set page number 
                st = pd.DataFrame(tabula.read_pdf(file, pages=page)[0]).replace(np.nan, '') 
                
                if st.iloc[:1,:1].squeeze() == "Goalkeepers": # ensure what we're selecting is an MDS team sheet, not something else 
                    
                    # --------- filter and apply ---------- #
                    print('\033[1m\n')
                    print('=' * term_size.columns)
                    st.drop(list(st.filter(regex='Unnamed: 0')), axis=1, inplace=True)
                    st.rename(columns = { "Unnamed: 1" : "Nationality" },inplace=True)
                    print('\033[1m\n' + search + '\n')
                    print('=' * term_size.columns)
                    #display(st) # show the scouted teams
                    #print('\n')

                    # --------- strip special characters ---------- #
                    st.iloc[:,3:16] = st.iloc[:,3:16].map(lambda x: x.rstrip('*+-')) # 

                     # --------- break into groups ---------- #
                    s = st.eq(st.columns)
                    s_groups = [g.reset_index(drop=True) for _, g in st[~s.iloc[:, 0]].groupby(s.cumsum()[~s.iloc[:, 0]].iloc[:, 0])]
                    s_gks = s_groups[0].drop(index=0)
                    s_deff = s_groups[1].drop(index=0)
                    s_mid = s_groups[2].drop(index=0)
                    s_att = s_groups[3].drop(index=0)

                    # --------- rename cols ---------- #
                    s_deff = s_deff.rename(columns={'Dis': 'Agg', 'Han': 'Tac', 'Ref':'Jud','Crs':'Vis'})
                    s_mid = s_mid.rename(columns={'Dis': 'Agg', 'Han': 'Tac', 'Ref':'Jud','Crs':'Vis'})
                    s_att = s_att.rename(columns={'Dis': 'Agg', 'Han': 'Tac', 'Ref':'Jud','Crs':'Vis'})

                    # --------- split ID and names ---------- #
                    s_gks[['ID', 'Name']] = s_gks['ID Name'].str.split(' ', n=1, expand=True)
                    s_gks.drop(columns="ID Name",axis=1, inplace=True)
                    s_gks = s_gks[["ID", "Name", "Age", "Foot", "Sho", "Mov","Pas","Con","Spe","Sta","Hea","Str","Dis","Han","Ref","Crs","OA","SA", "Nationality", "Price"]]


                    
                    # --------- Calculate PV ---------- #
                    s_gks['GK'] = s_gks[['Dis', 'Han', 'Ref','Crs']].astype(int).sum(axis = 1, skipna = True)
                    
                    s_deff['CB'] = s_deff[['Hea', 'Str', 'Tac','Jud']].astype(int).sum(axis = 1, skipna = True)
                    s_deff['FB'] = s_deff[['Spe', 'Sta', 'Agg','Tac']].astype(int).sum(axis = 1, skipna = True)
                    s_deff['SW'] = s_deff[['Pas', 'Con', 'Tac','Jud']].astype(int).sum(axis = 1, skipna = True)
                    s_deff['WB'] = s_deff[['Mov', 'Pas', 'Spe','Sta']].astype(int).sum(axis = 1, skipna = True)

                    s_mid['CM'] = s_mid[['Pas', 'Sta', 'Hea','Tac']].astype(int).sum(axis = 1, skipna = True)
                    s_mid['AM'] = s_mid[['Str', 'Agg', 'Tac','Jud']].astype(int).sum(axis = 1, skipna = True)
                    s_mid['PL'] = s_mid[['Pas', 'Con', 'Jud','Vis']].astype(int).sum(axis = 1, skipna = True)
                    s_mid['FR'] = s_mid[['Sho', 'Mov', 'Pas','Con']].astype(int).sum(axis = 1, skipna = True)
                    s_mid['WG'] = s_mid[['Pas', 'Con', 'Spe','Sta']].astype(int).sum(axis = 1, skipna = True)

                    s_att['WF'] = s_att[['Sho', 'Mov', 'Con','Spe']].astype(int).sum(axis = 1, skipna = True)
                    s_att['IF'] = s_att[['Pas', 'Con', 'Jud','Vis']].astype(int).sum(axis = 1, skipna = True)
                    s_att['CF'] = s_att[['Sho', 'Mov', 'Str','Agg']].astype(int).sum(axis = 1, skipna = True)
                    s_att['TM'] = s_att[['Con', 'Hea', 'Str','Agg']].astype(int).sum(axis = 1, skipna = True)

                    # --------- don't show low PVs ---------- #
                    s_gks['GK'] = s_gks['GK'].astype(int); s_gks['GK'] = np.where(s_gks['GK'] < s_PV, "", s_gks['GK'])

                    s_deff['CB'] = s_deff['CB'].astype(int); s_deff['CB'] = np.where(s_deff['CB'] < s_PV, "", s_deff['CB'])
                    s_deff['SW'] = s_deff['SW'].astype(int); s_deff['SW'] = np.where(s_deff['SW'] < s_PV, "", s_deff['SW'])
                    s_deff['WB'] = s_deff['WB'].astype(int); s_deff['WB'] = np.where(s_deff['WB'] < s_PV, "", s_deff['WB'])
                    s_deff['FB'] = s_deff['FB'].astype(int); s_deff['FB'] = np.where(s_deff['FB'] < s_PV, "", s_deff['FB'])
                    
                    s_mid['CM'] = s_mid['CM'].astype(int); s_mid['CM'] = np.where(s_mid['CM'] < s_PV, "", s_mid['CM'])
                    s_mid['AM'] = np.where(s_mid['AM'] < s_PV, "", s_mid['AM'])
                    s_mid['PL'] = np.where(s_mid['PL'] < s_PV, "", s_mid['PL'])
                    s_mid['FR'] = np.where(s_mid['FR'] < s_PV, "", s_mid['FR'])
                    s_mid['WG'] = s_mid['WG'].astype(int); s_mid['WG'] = np.where(s_mid['WG'] < s_PV, "", s_mid['WG'])
    
                    s_att['WF'] = s_att['WF'].astype(int); s_att['WF'] = np.where(s_att['WF'] < s_PV, "", s_att['WF'])
                    s_att['IF'] = np.where(s_att['IF'] < s_PV, "", s_att['IF'])
                    s_att['TM'] = np.where(s_att['TM'] < s_PV, "", s_att['TM'])
                    s_att['CF'] = np.where(s_att['CF'] < s_PV, "", s_att['CF'])


                    # --------- Show Players by Section ---------- #
                    display("Goalkeepers",s_gks.style.background_gradient(axis=None, subset=['Spe','Dis','Crs']),
                            "Defenders",s_deff.style.background_gradient(axis=None, subset=['Spe','Agg','Vis']),
                            "Midfielders",s_mid.style.background_gradient(axis=None, subset=['Spe','Agg','Vis']),
                            "Attackers",s_att.style.background_gradient(axis=None, subset=['Spe','Agg','Vis'])
                           )
                
                else: # if the searched-for text isn't in the PDF with a first cell of "Goalkeepers" - i.e. isn't a team we've scouted for, skip it
                    pass
                    
            else: # if list element is not in the page text, do nothing
                pass
    pdf_file.close()
    
#search_scouted(i) # pass each list element to the function search_scouted()

for i in search_MDS_4_scouts: # for each element in scouts
    result = search_scouted(i) # get the element and send to function search_scouted
# Out:
# ['Ascoli',
#  'Cannes',
#  'Douane',
#  'Santos Laguna',
#  'Incheon United',
#  'Ionikos',
#  'Longford Town',
#  'Motherwell',
#  'Excelsior Mouscron',
#  'Las Palmas']
# ========================================================================================================================
#
# Ascoli
#
# ========================================================================================================================
# 'Goalkeepers'
# <style type="text/css">
# #T_1416b_row0_col8, #T_1416b_row0_col12, #T_1416b_row1_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1416b_row0_col15, #T_1416b_row1_col15, #T_1416b_row2_col12 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_1416b_row1_col8, #T_1416b_row2_col8, #T_1416b_row2_col15 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_1416b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1416b_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_1416b_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_1416b_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T
level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_63c6e_level0_col2" class="col_heading level0 col2" >Foot</th>
#       <th id="T_63c6e_level0_col3" class="col_heading level0 col3" >Sho</th>
#       <th id="T_63c6e_level0_col4" class="col_heading level0 col4" >Mov</th>
#       <th id="T_63c6e_level0_col5" class="col_heading level0 col5" >Pas</th>
#       <th id="T_63c6e_level0_col6" class="col_heading level0 col6" >Con</th>
#       <th id="T_63c6e_level0_col7" class="col_heading level0 col7" >Spe</th>
#       <th id="T_63c6e_level0_col8" class="col_heading level0 col8" >Sta</th>
#       <th id="T_63c6e_level0_col9" class="col_heading level0 col9" >Hea</th>
#       <th id="T_63c6e_level0_col10" class="col_heading level0 col10" >Str</th>
#       <th id="T_63c6e_level0_col11" class="col_heading level0 col11" >Agg</th>
#       <th id="T_63c6e_level0_col12" class="col_heading level0 col12" >Tac</th>
#       <th id="T_63c6e_level0_col13" class="col_heading level0 col13" >Jud</th>
#       <th id="T_63c6e_level0_col14" class="col_heading level0 col14" >Vis</th>
#       <th id="T_63c6e_level0_col15" class="col_heading level0 col15" >OA</th>
#       <th id="T_63c6e_level0_col16" class="col_heading level0 col16" >SA</th>
#       <th id="T_63c6e_level0_col17" class="col_heading level0 col17" >Nationality</th>
#       <th id="T_63c6e_level0_col18" class="col_heading level0 col18" >Price</th>
#       <th id="T_63c6e_level0_col19" class="col_heading level0 col19" >CB</th>
#       <th id="T_63c6e_level0_col20" class="col_heading level0 col20" >FB</th>
#       <th id="T_63c6e_level0_col21" class="col_heading level0 col21" >SW</th>
#       <th id="T_63c6e_level0_col22" class="col_heading level0 col22" >WB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63c6e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_63c6e_row0_col0" class="data row0 col0" >WICE E Wichne</td>
#       <td id="T_63c6e_row0_col1" class="data row0 col1" >27</td>
#       <td id="T_63c6e_row0_col2" class="data row0 col2" >R</td>
#       <td id="T_63c6e_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_63c6e_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_63c6e_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_63c6e_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_63c6e_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_63c6e_row0_col8" class="data row0 col8" >9</td>
#       <td id="T_63c6e_row0_col9" class="data row0 col9" >7</td>
#       <td id="T_63c6e_row0_col10" class="data row0 col10" >7</td>
#       <td id="T_63c6e_row0_col11" class="data row0 col11" >9</td>
#       <td id="T_63c6e_row0_col12" class="data row0 col12" >9</td>
#       <td id="T_63c6e_row0_col13" class="data row0 col13" >8</td>
#       <td id="T_63c6e_row0_col14" class="data row0 col14" >8</td>
#       <td id="T_63c6e_row0_col15" class="data row0 col15" >99</td>
#       <td id="T_63c6e_row0_col16" class="data row0 col16" ></td>
#       <td id="T_63c6e_row0_col17" class="data row0 col17" >Norwegian</td>
#       <td id="T_63c6e_row0_col18" class="data row0 col18" >£13,794,096</td>
#       <td id="T_63c6e_row0_col19" class="data row0 col19" ></td>
#       <td id="T_63c6e_row0_col20" class="data row0 col20" >36</td>
#       <td id="T_63c6e_row0_col21" class="data row0 col21" >34</td>
#       <td id="T_63c6e_row0_col22" class="data row0 col22" >35</td>
#     </tr>
#     <tr>
#       <th id="T_63c6e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_63c6e_row1_col0" class="data row1 col0" >MKAK S Mannini</td>
#       <td id="T_63c6e_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_63c6e_row1_col2" class="data row1 col2" >R</td>
#       <td id="T_63c6e_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_63c6e_row1_col4" class="data row1 col4" >9</td>
#       <td id="T_63c6e_row1_col5" class="data row1 col5" >8</td>
#       <td id="T_63c6e_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_63c6e_row1_col7" class="data row1 col7" >10</td>
#       <td id="T_63c6e_row1_col8" class="data row1 col8" >8</td>
#       <td id="T
{
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_27aa0_row0_col14, #T_27aa0_row1_col14, #T_27aa0_row2_col14, #T_27aa0_row3_col14, #T_27aa0_row4_col11, #T_27aa0_row4_col14, #T_27aa0_row5_col11, #T_27aa0_row6_col7, #T_27aa0_row7_col11, #T_27aa0_row8_col14 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_27aa0_row2_col7, #T_27aa0_row3_col7, #T_27aa0_row5_col7, #T_27aa0_row6_col11, #T_27aa0_row7_col7, #T_27aa0_row8_col11 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_27aa0_row8_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_27aa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27aa0_level0_col0" class="col_heading level0 col0" >ID Name</th>
#       <th id="T_27aa0_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_27aa0_level0_col2" class="col_heading level0 col2" >Foot</th>
#       <th id="T_27aa0_level0_col3" class="col_heading level0 col3" >Sho</th>
#       <th id="T_27aa0_level0_col4" class="col_heading level0 col4" >Mov</th>
#       <th id="T_27aa0_level0_col5" class="col_heading level0 col5" >Pas</th>
#       <th id="T_27aa0_level0_col6" class="col_heading level0 col6" >Con</th>
#       <th id="T_27aa0_level0_col7" class="col_heading level0 col7" >Spe</th>
#       <th id="T_27aa0_level0_col8" class="col_heading level0 col8" >Sta</th>
#       <th id="T_27aa0_level0_col9" class="col_heading level0 col9" >Hea</th>
#       <th id="T_27aa0_level0_col10" class="col_heading level0 col10" >Str</th>
#       <th id="T_27aa0_level0_col11" class="col_heading level0 col11" >Agg</th>
#       <th id="T_27aa0_level0_col12" class="col_heading level0 col12" >Tac</th>
#       <th id="T_27aa0_level0_col13" class="col_heading level0 col13" >Jud</th>
#       <th id="T_27aa0_level0_col14" class="col_heading level0 col14" >Vis</th>
#       <th id="T_27aa0_level0_col15" class="col_heading level0 col15" >OA</th>
#       <th id="T_27aa0_level0_col16" class="col_heading level0 col16" >SA</th>
#       <th id="T_27aa0_level0_col17" class="col_heading level0 col17" >Nationality</th>
#       <th id="T_27aa0_level0_col18" class="col_heading level0 col18" >Price</th>
#       <th id="T_27aa0_level0_col19" class="col_heading level0 col19" >CM</th>
#       <th id="T_27aa0_level0_col20" class="col_heading level0 col20" >AM</th>
#       <th id="T_27aa0_level0_col21" class="col_heading level0 col21" >PL</th>
#       <th id="T_27aa0_level0_col22" class="col_heading level0 col22" >FR</th>
#       <th id="T_27aa0_level0_col23" class="col_heading level0 col23" >WG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27aa0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_27aa0_row0_col0" class="data row0 col0" >KMHP E Kraja</td>
#       <td id="T_27aa0_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_27aa0_row0_col2" class="data row0 col2" >R</td>
#       <td id="T_27aa0_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_27aa0_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_27aa0_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_27aa0_row0_col6" class="data row0 col6" >7</td>
#       <td id="T_27aa0_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_27aa0_row0_col8" class="data row0 col8" >9</td>
#       <td id="T_27aa0_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_27aa0_row0_col10" class="data row0 col10" >7</td>
#       <td id="T_27aa0_row0_col11" class="data row0 col11" >9</td>
#       <td id="T_27aa0_row0_col12" class="data row0 col12" >9</td>
#       <td id="T_27aa0_row0_col13" class="data row0 col13" >8</td>
#       <td id="T_27aa0_row0_col14" class="data row0 col14" >8</td>
#       <td id="T_27aa0_row0_col15" class="data row0 col15" >95</td>
#       <td id="T_27aa0_row0_col16" class="data row0 col16" ></td>
#       <td id="T_27aa0_row0_col17" class="data row0 col17" >Albanian</td>
#       <td id="T_27aa0_row0_col18" class="data row0 col18" >£13,398,575</td>
#       <td id="T_27aa0_row0_col19" class="data row0 col19" >36</td>
#       <td id="T_27aa0_row0_col20" class="data row0 col20" >33</td>
#       <td id="T_27aa0_row0_col21" class="data row0 col21" >32</td>
#       <td id="T_27aa0_row0_col22" class="data row0 col22" ></td>
#       <td id="T_27aa0_row0_col23" class="data row0 col23" ></td>
#     </tr>
#     <tr>
#       <th id="T_27aa0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_27aa0_row1_col0" class="data row1 col0" >DRIE S D'Uffizi</td>
#       <td id="T_27aa0_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_27aa0_row1_col2" class="data row1 col2" >R</td>
#       <td id="T_27aa0_row1_col3" class="data row1 col3" >9</td>
#       <td id="T_27aa0_row1_col4" class="data row1 col4" >9</td>
#       <td id="T_27aa0_row1_col5" class="data row1 col5" >9</td>
#       <td id="T_27aa0_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_27aa0_row1_col7" class="data row1 col7" >6</td>
#       <td id="T_27aa0_row1_col8" class="data row1 col8" >7</td>
#       <td id="T_27aa0_row1_col9" class="data row1 col9" >7</td>
#       <td id="T_27aa0_row1_col10" class="data row1 col10" >7</td>
#       <td id="T_27aa0_row1_col11" class="data row1 col11" >9</td>
#       <td id="T_27aa0_row1_col12" class="data row1 col12" >7</td>
#       <td id="T_27aa0_row1_col13" class="data row1 col13" >7</td>
#       <td id="T_27aa0_row1_col14" class="data row1 col14" >8</td>
#       <td id="T_27aa0_row1_col15" class="data row1 col15" >94</td>
#       <td id="T_27aa0_row1_col16" class="data row1 col16" ></td>
#       <td id="T_27aa0_row1_col17" class="data row1 col17" >Italian</td>
#       <td id="T_27aa0_row1_col18" class="data row1 col18" >£14,683,061</td>
#       <td id="T_27aa0_row1_col19" class="data row1 col19" ></td>
#       <td id="T_27aa0_row1_col20" class="data row1 col20" ></td>
#       <td id="T_27aa0_row1_col21" class="data row1 col21" >33</td>
#       <td id="T_27aa0_row1_col22" class="data row1 col22" >36</td>
#       <td id="T_27aa0_row1_col23" class="data row1 col23" ></td>
#     </tr>
#     <tr>
#       <th id="T_27aa0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_27aa0_row2_col0" class="data row2 col0" >LUUX G La Vista</td>
#       <td id="T_27aa0_row2_col1" class="data row2 col1" >22</td>
#       <td id="T_27aa0_row2_col2" class="data row2 col2" >R</td>
#       <td id="T_27aa0_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_27aa0_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_27aa0_row2_col5" class="data row2 col5" >7</td>
#       <td id="T_27aa0_row2_col6" class="data row2 col6" >7</td>
#       <td id="T_27aa0_row2_col7" class="data row2 col7" >7</td>
#       <td id="T_27aa0_row2_col8" class="data row2 col8" >10</td>
#       <td id="T_27aa0_row2_col9" class="data row2 col9" >10</td>
#       <td id="T_27aa0_row2_col10" class="data row2 col10" >7</td>
#       <td id="T_27aa0_row2_col11" class="data row2 col11" >9</td>
#       <td id="T_27aa0_row2_col12" class="data row2 col12" >9</td>
#       <td id="T_27aa0_row2_col13" class="data row2 col13" >7</td>
#       <td id="T_27aa0_row2_col14" class="data row2 col14" >8</td>
#       <td id="T_27aa0_row2_col15" class="data row2 col15" >94</td>
#       <td id="T_27aa0_row2_col16" class="data row2 col16" >Inx</td>
#       <td id="T_27aa0_row2_col17" class="data row2 col17" >Italian</td>
#       <td id="T_27aa0_row2_col18" class="data row2 col18" >£14,404,482</td>
#       <td id="T_27aa0_row2_col19" class="data row2 col19" >36</td>
#       <td id="T_27aa0_row2_col20" class="data row2 col20" >32</td>
#       <td id="T_27aa0_row2_col21" class="data row2 col21" ></td>
#       <td id="T_27aa0_row2_col22" class="data row2 col22" ></td>
#       <td id="T_27aa0_row2_col23" class="data row2 col23" ></td>
#     </tr>
#     <tr>
#       <th id="T_27aa0_level0_row3" class="row_heading level0 row3" >4</th>
#       <
# 'Attackers'
# <style type="text/css">
# #T_238ec_row0_col7, #T_238ec_row0_col11, #T_238ec_row1_col7, #T_238ec_row1_col11, #T_238ec_row3_col7, #T_238ec_row4_col11, #T_238ec_row4_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_238ec_row0_col14, #T_238ec_row1_col14, #T_238ec_row4_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_238ec_row2_col7, #T_238ec_row2_col11, #T_238ec_row2_col14, #T_238ec_row3_col11, #T_238ec_row3_col14 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_238ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_238ec_level0_col0" class="col_heading level0 col0" >ID Name</th>
#       <th id="T_238ec_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_238ec_level0_col2" class="col_heading level0 col2" >Foot</th>
#       <th id="T_238ec_level0_col3" class="col_heading level0 col3" >Sho</th>
#       <th id="T_238ec_level0_col4" class="col_heading level0 col4" >Mov</th>
#       <th id="T_238ec_level0_col5" class="col_heading level0 col5" >Pas</th>
#       <th id="T_238ec_level0_col6" class="col_heading level0 col6" >Con</th>
#       <th id="T_238ec_level0_col7" class="col_heading level0 col7" >Spe</th>
#       <th id="T_238ec_level0_col8" class="col_heading level0 col8" >Sta</th>
#       <th id="T_238ec_level0_col9" class="col_heading level0 col9" >Hea</th>
#       <th id="T_238ec_level0_col10" class="col_heading level0 col10" >Str</th>
#       <th id="T_238ec_level0_col11" class="col_heading level0 col11" >Agg</th>
#       <th id="T_238ec_level0_col12" class="col_heading level0 col12" >Tac</th>
#       <th id="T_238ec_level0_col13" class="col_heading level0 col13" >Jud</th>
#       <th id="T_238ec_level0_col14" class="col_heading level0 col14" >Vis</th>
#       <th id="T_238ec_level0_col15" class="col_heading level0 col15" >OA</th>
#       <th id="T_238ec_level0_col16" class="col_heading level0 col16" >SA</th>
#       <th id="T_238ec_level0_col17" class="col_heading level0 col17" >Nationality</th>
#       <th id="T_238ec_level0_col18" class="col_heading level0 col18" >Price</th>
#       <th id="T_238ec_level0_col19" class="col_heading level0 col19" >WF</th>
#       <th id="T_238ec_level0_col20" class="col_heading level0 col20" >IF</th>
#       <th id="T_238ec_level0_col21" class="col_heading level0 col21" >CF</th>
#       <th id="T_238ec_level0_col22" class="col_heading level0 col22" >TM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T
level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_238ec_row2_col0" class="data row2 col0" >CGKO R Chiecchi</td>
#       <td id="T_238ec_row2_col1" class="data row2 col1" >24</td>
#       <td id="T_238ec_row2_col2" class="data row2 col2" >R</td>
#       <td id="T_238ec_row2_col3" class="data row2 col3" >9</td>
#       <td id="T_238ec_row2_col4" class="data row2 col4" >9</td>
#       <td id="T_238ec_row2_col5" class="data row2 col5" >8</td>
#       <td id="T_238ec_row2_col6" class="data row2 col6" >7</td>
#       <td id="T_238ec_row2_col7" class="data row2 col7" >8</td>
#       <td id="T_238ec_row2_col8" class="data row2 col8" >9</td>
#       <td id="T_238ec_row2_col9" class="data row2 col9" >7</td>
#       <td id="T_238ec_row2_col10" class="data row2 col10" >9</td>
#       <td id="T_238ec_row2_col11" class="data row2 col11" >8</td>
#       <td id="T_238ec_row2_col12" class="data row2 col12" >6</td>
#       <td id="T_238ec_row2_col13" class="data row2 col13" >7</td>
#       <td id="T_238ec_row2_col14" class="data row2 col14" >8</td>
#       <td id="T_238ec_row2_col15" class="data row2 col15" >95</td>
#       <td id="T_238ec_row2_col16" class="data row2 col16" >Gam/Gsi</td>
#       <td id="T_238ec_row2_col17" class="data row2 col17" >Italian</td>
#       <td id="T_238ec_row2_col18" class="data row2 col18" >£14,900,805</td>
#       <td id="T_238ec_row2_col19" class="data row2 col19" >33</td>
#       <td id="T_238ec_row2_col20" class="data row2 col20" ></td>
#       <td id="T_238ec_row2_col21" class="data row2 col21" >35</td>
#       <td id="T_238ec_row2_col22" class="data row2 col22" ></td>
#     </tr>
#     <tr>
#       <th id="T_238ec_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_238ec_row3_col0" class="data row3 col0" >MSVT G Manzari</td>
#       <td id="T_238ec_row3_col1" class="data row3 col1" >24</td>
#       <td id="T_238ec_row3_col2" class="data row3 col2" >L</td>
#       <td id="T_238ec_row3_col3" class="data row3 col3" >9</td>
#       <td id="T_238ec_row3_col4" class="data row3 col4" >9</td>
#       <td id="T_238ec_row3_col5" class="data row3 col5" >7</td>
#       <td id="T_238ec_row3_col6" class="data row3 col6" >9</td>
#       <td id="T_238ec_row3_col7" class="data row3 col7" >9</td>
#       <td id="T_238ec_row3_col8" class="data row3 col8" >7</td>
#       <td id="T_2
# ========================================================================================================================
#
# Cannes
#
# ========================================================================================================================
# 'Goalkeepers'
# <style type="text/css">
# #T_d524f_row0_col8 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d524f_row0_col12, #T_d524f_row1_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d524f_row0_col15, #T_d524f_row1_col12, #T_d524f_row1_col15 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d524f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d524f_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_d524f_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_d524f_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_d524f_level0_col3" class="col_heading level0 col3" >Foot</th>
#       <th id="T_d524f_level0_col4" class="col_heading level0 col4" >Sho</th>
#       <th id="T_d524f_level0_col5" class="col_heading level0 col5" >Mov</th>
#       <th id="T_d524f_level0_col6" class="col_heading level0 col6" >Pas</th>
#       <th id="T_d524f_level0_col7" class="col_heading level0 col7" >Con</th>
#       <th id="T_d524f_level0_col8" class="col_heading level0 col8" >Spe</th>
#       <th id="T_d524f_level0_col9" class="col_heading level0 col9" >Sta</th>
#       <th id="T_d524f_level0_col10" class="col_heading level0 col10" >Hea</th>
#       <th id="T_d524f_level0_col11" class="col_heading level0 col11" >Str</th>
#       <th id="T_d524f_level0_col12" class="col_heading level0 col12" >Dis</th>
#       <th id="T_d524f_level0_col13" class="col_heading level0 col13" >Han</th>
#       <th id="T_d524f_level0_col14" class="col_heading level0 col14" >Ref</th>
#       <th id="T_d524f_level0_col15" class="col_heading level0 col15" >Crs</th>
#       <th id="T_d524f_level0_col16" class="col_heading level0 col16" >OA</th>
#       <th id="T_d524f_level0_col17" class="col_heading level0 col17" >SA</th>
#       <th id="T_d524f_level0_col18" class="col_heading level0 col18" >Nationality</th>
#       <th id="T_d524f_level0_col19" class="col_heading level0 col19" >Price</th>
#       <th id="T_d524f_level0_col20" class="col_heading level0 col20" >GK</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d524f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d524f_row0_col0" class="data row0 col0" >BTDA</td>
#       <td id="T_d524f_row0_col1" class="data row0 col1" >N Bahoya</td>
#       <td id="T_d524f_row0_col2" class="data row0 col2" >23</td>
#       <td id="T_d524f_row0_col3" class="data row0 col3" >R</td>
#       <td id="T_d524f_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_d524f_row0_col5" class="data row0 col5" >7</td>
#       <td id="T_d524f_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_d524f_row0_col7" class="data row0 col7" >8</td>
#       <td id="T_d524f_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_d524f_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_d524f_row0_col10" class="data row0 col10" >7</td>
#       <td id="T_d524f_row0_col11" class="data row0 col11" >8</td>
#       <td id="T_d524f_row0_col12" class="data row0 col12" >9</td>
#       <td id="T_d524f_row0_col13" class="data row0 col13" >8</td>
#       <td id="T_d524f_row0_col14" class="data row0 col14" >9</td>
#       <td id="T_d524f_row0_col15" class="data row0 col15" >8</td>
#       <td id="T_d524f_row0_col16" class="data row0 col16" >95</td>
#       <td id="T_d524f_row0_col17" class="data row0 col17" >Inx</td>
#       <td id="T_d524f_row0_col18" class="data row0 col18" >French</td>
#       <td id="T_d524f_row0_col19" class="data row0 col19" >£7,117,402</td>
#       <td id="T_d524f_row0_col20" class="data row0 col20" >34</td>
#     </tr>
#     <tr>
#       <th id="T_d524f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d524f_row1_col0" class="data row1 col0" >LMCJ</td>
#       <td id="T_d524f_row1_col1" class="data row1 col1" >B Landrin</td>
#       <td id="T_d524f_row1_col2" class="data row1 col2" >21</td>
#       <td id="T_d524f_row1_col3" class="data row1 col3" >R</td>
#       <td id="T_d524f_row1_col4" class="data row1 col4" >8</td>
#       <td id="T_d524f_row1_col5" class="data row1 col5" >5</td>
#       <td id="T_d524f_row1_col6" class="data row1 col6" >7</td>
#       <td id="T_d524f_row1_col7" class="data row1 col7" >8</td>
#       <td id="T_d524f_row1_col8" class="data row1 col8" >9</td>
#       <td id="T_d524f_row1_col9" class="data row1 col9" >8</td>
#       <td id="T_d524f_row1_col10" class="data row1 col10" >9</td>
#       <td id="T_d524f_row1_col11" class="data row1 col11" >7</td>
#       <td id="T_d524f_row1_col12" class="data row1 col12" >8</td>
#       <td id="T_d524f_row1_col13" class="data row1 col13" >10</td>
#       <td id="T_d524f_row1_col14" class="data row1 col14" >8</td>
#       <td id="T_d524f_row1_col15" class="data row1 col15" >8</td>
#       <td id="T_d524f_row1_col16" class="data row1 col16" >95</td>
#       <td id="T_d524f_row1_col17" class="data row1 col17" >Inx</td>
#       <td id="T_d524f_row1_col18" class="data row1 col18" >French</td>
#       <td id="T_d524f_row1_col19" class="data row1 col19" >£7,514,628</td>
#       <td id="T_d524f_row1_col20" class="data row1 col20" >34</td>
#     </tr>
#   </tbody>
# </table>
# 'Defenders'
# <style type="text/css">
# #T_2be38_row0_col7, #T_2be38_row4_col7, #T_2be38_row4_col14, #T_2be38_row6_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2be38_row0_col11, #T_2be38_row2_col7 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2be38_row0_col14, #T_2be38_row1_col7, #T_2be38_row3_col14, #T_2be38_row7_col7 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_2be38_row1_col11, #T_2be38_row1_col14, #T_2be38_row2_col14, #T_2be38_row3_col11, #T_2be38_row5_col11, #T_2be38_row5_col14, #T_2be38_row7_col14 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_2be38_row2_col11, #T_2be38_row3_col7, #T_2be38_row6_col14, #T_2be38_row7_col11 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_2be38_row4_col11 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_2be38_row5_col7, #T_2be38_row6_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_2be38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2be38_level0_col0" class="col_heading level0 col0" >ID Name</th>
#       <th id="T_2be38_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_2be38_level0_col2" class="col_heading level0 col2" >Foot</th>
#       <th id="T_2be38_level0_col3" class="col_heading level0 col3" >Sho</th>
#       <th id="T_2be38_level0_col4" class="col_heading level0 col4" >Mov</th>
#       <th id="T_2be38_level0_col5" class="col_heading level0 col5" >Pas</th>
#       <th id="T_2be38_level0_col6" class="col_heading level0 col6" >Con</th>
#       <th id="T_2be38_level0_col7" class="col_heading level0 col7" >Spe</th>
#       <th id="T_2be38_level0_col8" class="col_heading level0 col8" >Sta</th>
#       <th id="T_2be38_level0_col9" class="col_heading level0 col9" >Hea</th>
#       <th id="T_2be38_level0_col10" class="col_heading level0 col10" >Str</th>
#       <th id="T_2be38_level0_col11" class="col_heading level0 col11" >Agg</th>
#       <th id="T_2be38_level0_col12" class="col_heading level0 col12" >Tac</th>
#       <th id="T_2be38_level0_col13" class="col_heading level0 col13" >Jud</th>
#       <th id="T_2be38_level0_col14" class="col_heading level0 col14" >Vis</th>
#       <th id="T_2be38_level0_col15" class="col_heading level0 col15" >OA</th>
#       <th id="T_2be38_level0_col16" class="col_heading level0 col16" >SA</th>
#       <th id="T_2be38_level0_col17" class="col_heading level0 col17" >Nationality</th>
#       <th id="T_2be38_level0_col18" class="col_heading level0 col18" >Price</th>
#       <th id="T_2be38_level0_col19" class="col_heading level0 col19" >CB</th>
#       <th id="T_2be38_level0_col20" class="col_heading level0 col20" >FB</th>
#       <th id="T_2be38_level0_col21" class="col_heading level0 col21" >SW</th>
#       <th id="T_2be38_level0_col22" class="col_heading level0 col22" >WB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2be38_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2be38_row0_col0" class="data row0 col0" >AGAD D Agathe</td>
#       <td id="T_2be38_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_2be38_row0_col2" class="data row0 col2" >R</td>
#       <td id="T_2be38_row0_col3" class="data row0 col3" >7</td>
#       <td id="T
#       <td id="T_2be38_row2_col12" class="data row2 col12" >9</td>
#       <td id="T_2be38_row2_col13" class="data row2 col13" >8</td>
#       <td id="T_2be38_row2_col14" class="data row2 col14" >8</td>
#       <td id="T_2be38_row2_col15" class="data row2 col15" >95</td>
#       <td id="T_2be38_row2_col16" class="data row2 col16" ></td>
#       <td id="T_2be38_row2_col17" class="data row2 col17" >French</td>
#       <td id="T_2be38_row2_col18" class="data row2 col18" >£6,381,878</td>
#       <td id="T_2be38_row2_col19" class="data row2 col19" >35</td>
#       <td id="T_2be38_row2_col20" class="data row2 col20" ></td>
#       <td id="T_2be38_row2_col21" class="data row2 col21" >33</td>
#       <td id="T_2be38_row2_col22" class="data row2 col22" ></td>
#     </tr>
#     <tr>
#       <th id="T_2be38_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_2be38_row3_col0" class="data row3 col0" >MLPU L Mary</td>
#       <td id="T_2be38_row3_col1" class="data row3 col1" >24</td>
#       <td id="T_2be38_row3_col2" class="data row3 col2" >R</td>
#       <td id="T_2be38_row3_col3" class="data
# 'Midfielders'
# <style type="text/css">
# #T_b28ee_row0_col7, #T_b28ee_row0_col11, #T_b28ee_row1_col11, #T_b28ee_row3_col14, #T_b28ee_row5_col11, #T_b28ee_row6_col11 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_b28ee_row0_col14, #T_b28ee_row1_col14, #T_b28ee_row2_col7, #T_b28ee_row3_col7, #T_b28ee_row3_col11, #T_b28ee_row5_col7, #T_b28ee_row5_col14, #T_b28ee_row6_col7, #T_b28ee_row6_col14 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_b28ee_row1_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b28ee_row2_col11, #T_b28ee_row4_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b28ee_row2_col14, #T_b28ee_row4_col7, #T_b28ee_row4_col11 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# </style>
# <table id="T_b28ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b28ee_level0_col0" class="col_heading level0 col0" >ID Name</th>
#       <th id="T_b28ee_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_b28ee_level0_col2" class="col_heading level0 col2" >Foot</th>
#       <th id="T_b28ee_level0_col3" class="col_heading level0 col3" >Sho</th>
#       <th id="T_b28ee_level0_col4" class="col_heading level0 col4" >Mov</th>
#       <th id="T_b28ee_level0_col5" class="col_heading level0 col5" >Pas</th>
#       <th id="T_b28ee_level0_col6" class="col_heading level0 col6" >Con</th>
#       <th id="T_b28ee_level0_col7" class="col_heading level0 col7" >Spe</th>
#       <th id="T_b28ee_level0_col8" class="col_heading level0 col8" >Sta</th>
#       <th id="T_b28ee_level0_col9" class="col_heading level0 col9" >Hea</th>
#       <th id="T_b28ee_level0_col10" class="col_heading level0 col10" >Str</th>
#       <th id="T_b28ee_level0_col11" class="col_heading level0 col11" >Agg</th>
#       <th id="T_b28ee_level0_col12" class="col_heading level0 col12" >Tac</th>
#       <th id="T_b28ee_level0_col13" class="col_heading level0 col13" >Jud</th>
#       <th id="T_b28ee_level0_col14" class="col_heading level0 col14" >Vis</th>
#       <th id="T_b28ee_level0_col15" class="col_heading level0 col15" >OA</th>
#       <th id="T_b28ee_level0_col16" class="col_heading level0 col16" >SA</th>
#       <th id="T_b28ee_level0_col17" class="col_heading level0 col17" >Nationality</th>
#       <th id="T_b28ee_level0_col18" class="col_heading level0 col18" >Price</th>
#       <th id="T_b28ee_level0_col19" class="col_heading level0 col19" >CM</th>
#       <th id="T_b28ee_level0_col20" class="col_heading level0 col20" >AM</th>
#       <th id="T_b28ee_level0_col21" class="col_heading level0 col21" >PL</th>
#       <th id="T_b28ee_level0_col22" class="col_heading level0 col22" >FR</th>
#       <th id="T_b28ee_level0_col23" class="col_heading level0 col23" >WG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b28ee_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b28ee_row0_col0" class="data row0 col0" >BBXJ B Bellone</td>
#       <td id="T_b28ee_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_b28ee_row0_col2" class="data row0 col2" >L</td>
#       <td id="T_b28ee_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_b28ee_row0_col4" class="data row0 col4" >7</td>
#       <td id="T_b28ee_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_b28ee_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_b28ee_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_b28ee_row0_col8" class="data row0 col8" >10</td>
#       <td id="T_b28ee_row0_col9" class="data row0 col9" >7</td>
#       <td id="T_b28ee_row0_col10" class="data row0 col10" >9</td>
# ...
# #T_ebd59_row0_col7, #T_ebd59_row2_col14, #T_ebd59_row5_col14, #T_ebd59_row6_col11 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_ebd59_row0_col11, #T_ebd59_row1_col7, #T_ebd59_row3_col14, #T_ebd59_row4_col7, #T_ebd59_row4_col14, #T_ebd59_row7_col7, #T_ebd59_row7_col11 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_ebd59_row0_col14, #T_ebd59_row1_col14, #T_ebd59_row2_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ebd59_row1_col11, #T_ebd59_row2_col7, #T_ebd59_row3_col7, #T_ebd59_row4_col11, #T_ebd59_row5_col7, #T_ebd59_row6_col7, #T_ebd59_row6_col14 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_ebd59_row3_col11, #T_ebd59_row7_col14 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_ebd59_row5_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_ebd59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebd59_level0_col0" class="col_heading level0 col0" >ID Name</th>
#       <th id="T_ebd59_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_ebd59_level0_col2" class="col_heading level0 col2" >Foot</th>
#       <th id="T_ebd59_level0_col3" class="col_heading level0 col3" >Sho</th>
#       <th id="T_ebd59_level0_col4" class="col_heading level0 col4" >Mov</th>
#       <th id="T_ebd59_level0_col5" class="col_heading level0 col5" >Pas</th>
#       <th id="T_ebd59_level0_col6" class="col_heading level0 col6" >Con</th>
#       <th id="T_ebd59_level0_col7" class="col_heading level0 col7" >Spe</th>
#       <th id="T_ebd59_level0_col8" class="col_heading level0 col8" >Sta</th>
#       <th id="T_ebd59_level0_col9" class="col_heading level0 col9" >Hea</th>
#       <th id="T_ebd59_level0_col10" class="col_heading level0 col10" >Str</th>
#       <th id="T_ebd59_level0_col11" class="col_heading level0 col11" >Agg</th>
#       <th id="T_ebd59_level0_col12" class="col_heading level0 col12" >Tac</th>
#       <th id="T_ebd59_level0_col13" class="col_heading level0 col13" >Jud</th>
#       <th id="T_ebd59_level0_col14" class="col_heading level0 col14" >Vis</th>
#       <th id="T_ebd59_level0_col15" class="col_heading level0 col15" >OA</th>
#       <th id="T_ebd59_level0_col16" class="col_heading level0 col16" >SA</th>
level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_1085f_level0_col2" class="col_heading level0 col2" >Foot</th>
#       <th id="T_1085f_level0_col3" class="col_heading level0 col3" >Sho</th>
#       <th id="T_1085f_level0_col4" class="col_heading level0 col4" >Mov</th>
#       <th id="T_1085f_level0_col5" class="col_heading level0 col5" >Pas</th>
#       <th id="T_1085f_level0_col6" class="col_heading level0 col6" >Con</th>
#       <th id="T_1085f_level0_col7" class="col_heading level0 col7" >Spe</th>
#       <th id="T_1085f_level0_col8" class="col_heading level0 col8" >Sta</th>
#       <th id="T_1085f_level0_col9" class="col_heading level0 col9" >Hea</th>
#       <th id="T_1085f_level0_col10" class="col_heading level0 col10" >Str</th>
#       <th id="T_1085f_level0_col11" class="col_heading level0 col11" >Agg</th>
#       <th id="T_1085f_level0_col12" class="col_heading level0 col12" >Tac</th>
#       <th id="T_1085f_level0_col13" class="col_heading level0 col13" >Jud</th>
#       <th id="T_1085f_level0_col14" class="col_heading level0 col14" >Vis</th>
#       <th id="T_1085f_level0_col15" class="col_heading level0 col15" >OA</th>
#       <th id="T_1085f_level0_col16" class="col_heading level0 col16" >SA</th>
#       <th id="T_1085f_level0_col17" class="col_heading level0 col17" >Nationality</th>
#       <th id="T_1085f_level0_col18" class="col_heading level0 col18" >Price</th>
#       <th id="T_1085f_level0_col19" class="col_heading level0 col19" >WF</th>
#       <th id="T_1085f_level0_col20" class="col_heading level0 col20" >IF</th>
#       <th id="T_1085f_level0_col21" class="col_heading level0 col21" >CF</th>
#       <th id="T_1085f_level0_col22" class="col_heading level0 col22" >TM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1085f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1085f_row0_col0" class="data row0 col0" >KADT T Kadewere</td>
#       <td id="T_1085f_row0_col1" class="data row0 col1" >28</td>
#       <td id="T_1085f_row0_col2" class="data row0 col2" >B</td>
#       <td id="T_1085f_row0_col3" class="data row0 col3" >9</td>
#       <td id="T_1085f_row0_col4" class="data row0 col4" >9</td>
#       <td id="T_1085f_row0_col5" class="data row0 col5" >7</td>
#       <td id="T_1085f_row0_col6" class="data row0 col6" >7</td>
#       <td id="T_1085f_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_1085f_row0_col8" class="data row0 col8" >7</td>
#       <td id="T_1085f_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_1085f_row0_col10" class="data row0 col10" >9</td>
#       <td id="T_1085f_row0_col11" class="data row0 col11" >9</td>
#       <td id="T_1085f_row0_col12" class="data row0 col12" >7</td>
#       <td id="T_1085f_row0_col13" class="data row0 col13" >7</td>
#       <td id="T_1085f_row0_col14" class="data row0 col14" >7</td>
#       <td id="T_1085f_row0_col15" class="data row0 col15" >96</td>
#       <td id="T_1085f_row0_col16" class="data row0 col16" >Dis/Gnt</td>
#       <td id="T_1085f_row0_col17" class="data row0 col17" >Zimbabwea</td>
#       <td id="T_1085f_row0_col18" class="data row0 col18" >£11,472,243</td>
#       <td id="T_1085f_row0_col19" class="data row0 col19" >34</td>
#       <td id="T_1085f_row0_col20" class="data row0 col20" ></td>
#       <td id="T_1085f_row0_col21" class="data row0 col21" >36</td>
#       <td id="T_1085f_row0_col22" class="data row0 col22" >34</td>
#     </tr>
#     <tr>
#       <th id="T_1085f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1085f_row1_col0" class="data row1 col0" >HOKJ R Hernandez</td>
#       <td id="T_1085f_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_1085f_row1_col2" class="data row1 col2" >R</td>
#       <td id="T_1085f_row1_col3" class="data row1 col3" >9</td>
#       <td id="T_1085f_row1_col4" class="data row1 col4" >9</td>
#       <td id="T_1085f_row1_col5" class="data row1 col5" >10</td>
#       <td id="T